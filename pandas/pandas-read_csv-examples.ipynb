# %%
import pandas as pd

X = pd.read_csv("pokemon.csv", header=None)

print("Type of X: ", type(X))

pd.read_csv(filepath_or_buffer = "pokemon.csv")
# Out:
# Type of X:  <class 'pandas.core.frame.DataFrame'>
#        #                       Name    Type 1  Type 2  Total   HP  Attack  \
# 0      1                  Bulbasaur     Grass  Poison    318   45      49
# 1      2                    Ivysaur     Grass  Poison    405   60      62
# 2      3                   Venusaur     Grass  Poison    525   80      82
# 3      3      VenusaurMega Venusaur     Grass  Poison    625   80     100
# 4      4                 Charmander      Fire     NaN    309   39      52
# 5      5                 Charmeleon      Fire     NaN    405   58      64
# 6      6                  Charizard      Fire  Flying    534   78      84
# 7      6  CharizardMega Charizard X      Fire  Dragon    634   78     130
# 8      6  CharizardMega Charizard Y      Fire  Flying    634   78     104
# 9      7                   Squirtle     Water     NaN    314   44      48
# 10     8                  Wartortle     Water     NaN    405   59      63
# ...

# %%
import pandas as pd

# Makes the passed rows header
pd.read_csv("pokemon.csv", header=[1, 2])
# Out:
#        1                  Bulbasaur     Grass  Poison  318   45   49       \
#        2                    Ivysaur     Grass  Poison  405   60   62   63
# 0      3                   Venusaur     Grass  Poison  525   80   82   83
# 1      3      VenusaurMega Venusaur     Grass  Poison  625   80  100  123
# 2      4                 Charmander      Fire     NaN  309   39   52   43
# 3      5                 Charmeleon      Fire     NaN  405   58   64   58
# 4      6                  Charizard      Fire  Flying  534   78   84   78
# 5      6  CharizardMega Charizard X      Fire  Dragon  634   78  130  111
# 6      6  CharizardMega Charizard Y      Fire  Flying  634   78  104   78
# 7      7                   Squirtle     Water     NaN  314   44   48   65
# 8      8                  Wartortle     Water     NaN  405   59   63   80
# 9      9                  Blastoise     Water     NaN  530   79   83  100
# 10     9    BlastoiseMega Blastoise     Water     NaN  630   79  103  120
# ...

# %%
import pandas as pd

# Skips the passed rows in new series
pd.read_csv("pokemon.csv", skiprows=[1, 2, 3, 4, 5])
# Out:
#        #                       Name    Type 1  Type 2  Total   HP  Attack  \
# 0      5                 Charmeleon      Fire     NaN    405   58      64
# 1      6                  Charizard      Fire  Flying    534   78      84
# 2      6  CharizardMega Charizard X      Fire  Dragon    634   78     130
# 3      6  CharizardMega Charizard Y      Fire  Flying    634   78     104
# 4      7                   Squirtle     Water     NaN    314   44      48
# 5      8                  Wartortle     Water     NaN    405   59      63
# 6      9                  Blastoise     Water     NaN    530   79      83
# 7      9    BlastoiseMega Blastoise     Water     NaN    630   79     103
# 8     10                   Caterpie       Bug     NaN    195   45      30
# 9     11                    Metapod       Bug     NaN    205   50      20
# 10    12                 Butterfree       Bug  Flying    395   60      45
# 11    13                     Weedle       Bug  Poison    195   40      35
# ...

# %%
import pandas as pd

X = pd.read_csv("pokemon.csv", header=None)

print(X.info())

X.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 801 entries, 0 to 800
# Data columns (total 13 columns):
# 0     801 non-null object
# 1     801 non-null object
# 2     801 non-null object
# 3     415 non-null object
# 4     801 non-null object
# 5     801 non-null object
# 6     801 non-null object
# 7     801 non-null object
# 8     801 non-null object
# 9     801 non-null object
# 10    801 non-null object
# 11    801 non-null object
# 12    801 non-null object
# dtypes: object(13)
# memory usage: 81.4+ KB
# None
#   0                      1       2       3      4   5       6        7   \
# 0  #                   Name  Type 1  Type 2  Total  HP  Attack  Defense
# 1  1              Bulbasaur   Grass  Poison    318  45      49       49
# 2  2                Ivysaur   Grass  Poison    405  60      62       63
# 3  3               Venusaur   Grass  Poison    525  80      82       83
# 4  3  VenusaurMega Venusaur   Grass  Poison    625  80     100      123
#
# ...

# %%
import pandas as pd

X = pd.read_csv("pokemon.csv", header=None)

print(type(X[1]))

print(X[1])
# Out:
# <class 'pandas.core.series.Series'>
# 0                           Name
# 1                      Bulbasaur
# 2                        Ivysaur
# 3                       Venusaur
# 4          VenusaurMega Venusaur
# 5                     Charmander
# 6                     Charmeleon
# 7                      Charizard
# 8      CharizardMega Charizard X
# 9      CharizardMega Charizard Y
# 10                      Squirtle
# 11                     Wartortle
# 12                     Blastoise
# 13       BlastoiseMega Blastoise
# 14                      Caterpie
# 15                       Metapod
# 16                    Butterfree
# 17                        Weedle
# 18                        Kakuna
# 19                      Beedrill
# 20         BeedrillMega Beedrill
# 21                        Pidgey
# 22                     Pidgeotto
# 23                       Pidgeot
# 24           PidgeotMega Pidgeot
# 25                       Rattata
# 26                      Raticate
# ...

# %%
import pandas as pd

X = pd.read_csv("pokemon.csv", header=None)

print(X[[1, 2]])
# Out:
#                              1         2
# 0                         Name    Type 1
# 1                    Bulbasaur     Grass
# 2                      Ivysaur     Grass
# 3                     Venusaur     Grass
# 4        VenusaurMega Venusaur     Grass
# 5                   Charmander      Fire
# 6                   Charmeleon      Fire
# 7                    Charizard      Fire
# 8    CharizardMega Charizard X      Fire
# 9    CharizardMega Charizard Y      Fire
# 10                    Squirtle     Water
# 11                   Wartortle     Water
# 12                   Blastoise     Water
# 13     BlastoiseMega Blastoise     Water
# 14                    Caterpie       Bug
# 15                     Metapod       Bug
# 16                  Butterfree       Bug
# 17                      Weedle       Bug
# 18                      Kakuna       Bug
# 19                    Beedrill       Bug
# 20       BeedrillMega Beedrill       Bug
# 21                      Pidgey    Normal
# ...
